# %%
# Import the dependencies
import pandas as pd
import numpy as np

# Use the Citipy module to determine city based on latitude and longitude
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(0.5)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | laukaa
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | mersing
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | beloha
# Processing Record 11 of Set 1 | saint anthony
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | moscow
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | shache
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | hays
# Processing Record 20 of Set 1 | martapura
# Processing Record 21 of Set 1 | skjervoy
# Processing Record 22 of Set 1 | hovd
# Processing Record 23 of Set 1 | zhigansk
# Processing Record 24 of Set 1 | seoul
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | svetlyy
# Processing Record 27 of Set 1 | del rio
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | havoysund
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | zemlyansk
# Processing Record 34 of Set 1 | santa cruz
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | llangefni
# Processing Record 37 of Set 1 | nelson bay
# Processing Record 38 of Set 1 | murdochville
# Processing Record 39 of Set 1 | brae
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | altamira
# Processing Record 45 of Set 1 | sistranda
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | broome
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | chardara
# Processing Record 1 of Set 2 | namatanai
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | dikson
# Processing Record 4 of Set 2 | massakory
# Processing Record 5 of Set 2 | nara
# Processing Record 6 of Set 2 | baherden
# Processing Record 7 of Set 2 | portland
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | tecoanapa
# Processing Record 10 of Set 2 | najran
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | hualmay
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | pochutla
# Processing Record 18 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | kwinana
# Processing Record 22 of Set 2 | payo
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | san patricio
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | paamiut
# Processing Record 27 of Set 2 | rio grande
# Processing Record 28 of Set 2 | kaeo
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | entre rios
# Processing Record 33 of Set 2 | gweta
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | carora
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | garhi khairo
# Processing Record 39 of Set 2 | monching
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | kalmunai
# Processing Record 43 of Set 2 | seguin
# Processing Record 44 of Set 2 | anloga
# Processing Record 45 of Set 2 | alacranes
# Processing Record 46 of Set 2 | pacific grove
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | faya
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | mount darwin
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | calvinia
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | yumen
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | berberati
# Processing Record 7 of Set 3 | sibolga
# Processing Record 8 of Set 3 | hvide sande
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | chapais
# Processing Record 12 of Set 3 | tete
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | jingdezhen
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | arman
# Processing Record 17 of Set 3 | steinbach
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | dunedin
# Processing Record 20 of Set 3 | fayetteville
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | tromso
# Processing Record 25 of Set 3 | wageningen
# Processing Record 26 of Set 3 | mandalgovi
# Processing Record 27 of Set 3 | nouadhibou
# Processing Record 28 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | gararu
# Processing Record 32 of Set 3 | buy
# Processing Record 33 of Set 3 | ludhiana
# Processing Record 34 of Set 3 | kamenka
# Processing Record 35 of Set 3 | komsomolskiy
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | ketchikan
# Processing Record 38 of Set 3 | lukoyanov
# Processing Record 39 of Set 3 | solnechnyy
# Processing Record 40 of Set 3 | munsingen
# Processing Record 41 of Set 3 | poya
# Processing Record 42 of Set 3 | birjand
# Processing Record 43 of Set 3 | fort nelson
# Processing Record 44 of Set 3 | knysna
# Processing Record 45 of Set 3 | pevek
# Processing Record 46 of Set 3 | yantal
# Processing Record 47 of Set 3 | kalemie
# Processing Record 48 of Set 3 | burica
# City not found. Skipping...
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | vagur
# Processing Record 1 of Set 4 | jeremie
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | puerto escondido
# Processing Record 6 of Set 4 | lagoa
# Processing Record 7 of Set 4 | oga
# Processing Record 8 of Set 4 | pizarro
# Processing Record 9 of Set 4 | havelock
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | preston
# Processing Record 12 of Set 4 | bose
# Processing Record 13 of Set 4 | mirabad
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | chabahar
# Processing Record 17 of Set 4 | el dorado
# Processing Record 18 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 4 | nemuro
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | miragoane
# Processing Record 23 of Set 4 | kannangad
# Processing Record 24 of Set 4 | cheltenham
# Processing Record 25 of Set 4 | san quintin
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | sur
# Processing Record 28 of Set 4 | onguday
# Processing Record 29 of Set 4 | turayf
# Processing Record 30 of Set 4 | longyearbyen
# Processing Record 31 of Set 4 | qatana
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | port blair
# Processing Record 36 of Set 4 | lasa
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | bulungu
# Processing Record 40 of Set 4 | clemencia
# Processing Record 41 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | horconcitos
# Processing Record 44 of Set 4 | marmande
# Processing Record 45 of Set 4 | campestre
# Processing Record 46 of Set 4 | atar
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | puerto madryn
# Processing Record 1 of Set 5 | quatre cocos
# Processing Record 2 of Set 5 | malpe
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | junagarh
# Processing Record 5 of Set 5 | dalfsen
# Processing Record 6 of Set 5 | lhokseumawe
# Processing Record 7 of Set 5 | belaya gora
# Processing Record 8 of Set 5 | ilo
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | sanand
# Processing Record 11 of Set 5 | flin flon
# Processing Record 12 of Set 5 | fortuna
# Processing Record 13 of Set 5 | kumphawapi
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 5 | tervel
# Processing Record 19 of Set 5 | weihe
# Processing Record 20 of Set 5 | betulia
# Processing Record 21 of Set 5 | baykalsk
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | hoganas
# Processing Record 24 of Set 5 | verkhnevilyuysk
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | charters towers
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | tiarei
# Processing Record 30 of Set 5 | kamina
# Processing Record 31 of Set 5 | kununurra
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | shirokiy
# Processing Record 35 of Set 5 | mumbwa
# Processing Record 36 of Set 5 | kieta
# Processing Record 37 of Set 5 | haines junction
# Processing Record 38 of Set 5 | alaca
# Processing Record 39 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | port hardy
# Processing Record 41 of Set 5 | saint-martin-boulogne
# Processing Record 42 of Set 5 | wala
# Processing Record 43 of Set 5 | satka
# Processing Record 44 of Set 5 | zwedru
# Processing Record 45 of Set 5 | alta floresta
# Processing Record 46 of Set 5 | sumbe
# Processing Record 47 of Set 5 | saint-georges
# Processing Record 48 of Set 5 | pecos
# Processing Record 49 of Set 5 | kudahuvadhoo
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 6 | djenne
# Processing Record 3 of Set 6 | kaitangata
# Processing Record 4 of Set 6 | quelimane
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | laem sing
# Processing Record 9 of Set 6 | sept-iles
# Processing Record 10 of Set 6 | andros town
# Processing Record 11 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 6 | sorong
# Processing Record 13 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-pierre
# Processing Record 15 of Set 6 | koumra
# Processing Record 16 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | castro
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | road town
# Processing Record 21 of Set 6 | arraial do cabo
# Processing Record 22 of Set 6 | doka
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | urengoy
# Processing Record 25 of Set 6 | togur
# Processing Record 26 of Set 6 | bella union
# Processing Record 27 of Set 6 | altay
# Processing Record 28 of Set 6 | airai
# Processing Record 29 of Set 6 | waingapu
# Processing Record 30 of Set 6 | mahebourg
# Processing Record 31 of Set 6 | san policarpo
# Processing Record 32 of Set 6 | kysyl-syr
# Processing Record 33 of Set 6 | ulaanbaatar
# Processing Record 34 of Set 6 | okhotsk
# Processing Record 35 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 6 | swellendam
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | poso
# Processing Record 39 of Set 6 | kamloops
# Processing Record 40 of Set 6 | neyvo-shaytanskiy
# Processing Record 41 of Set 6 | akdagmadeni
# Processing Record 42 of Set 6 | raudeberg
# Processing Record 43 of Set 6 | naze
# Processing Record 44 of Set 6 | vanimo
# Processing Record 45 of Set 6 | fairhope
# Processing Record 46 of Set 6 | koungou
# Processing Record 47 of Set 6 | scarborough
# Processing Record 48 of Set 6 | aksarka
# Processing Record 49 of Set 6 | malmesbury
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 7 | mackay
# Processing Record 3 of Set 7 | qaanaaq
# Processing Record 4 of Set 7 | champerico
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | kaseda
# Processing Record 7 of Set 7 | vao
# Processing Record 8 of Set 7 | amapa
# Processing Record 9 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 7 | sao filipe
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | medicine hat
# Processing Record 13 of Set 7 | la palma
# Processing Record 14 of Set 7 | merrill
# Processing Record 15 of Set 7 | yaring
# Processing Record 16 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 7 | elk point
# Processing Record 18 of Set 7 | beringovskiy
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | dingle
# Processing Record 21 of Set 7 | mitsamiouli
# Processing Record 22 of Set 7 | avanigadda
# Processing Record 23 of Set 7 | pulandian
# Processing Record 24 of Set 7 | matagami
# Processing Record 25 of Set 7 | vnanje gorice
# Processing Record 26 of Set 7 | irbeyskoye
# Processing Record 27 of Set 7 | ribeira grande
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | iwanai
# Processing Record 32 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 7 | kloulklubed
# Processing Record 34 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 7 | matay
# Processing Record 37 of Set 7 | rudolfov
# Processing Record 38 of Set 7 | itarema
# Processing Record 39 of Set 7 | pimentel
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | arlit
# Processing Record 42 of Set 7 | danville
# Processing Record 43 of Set 7 | gwadar
# Processing Record 44 of Set 7 | siauliai
# Processing Record 45 of Set 7 | ouallam
# Processing Record 46 of Set 7 | ayr
# Processing Record 47 of Set 7 | shieli
# Processing Record 48 of Set 7 | ostrovnoy
# Processing Record 49 of Set 7 | santa rosa
# Processing Record 50 of Set 7 | north bend
# Processing Record 1 of Set 8 | benguela
# Processing Record 2 of Set 8 | bilibino
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | loreto
# Processing Record 5 of Set 8 | reserva
# Processing Record 6 of Set 8 | labrea
# Processing Record 7 of Set 8 | tuni
# Processing Record 8 of Set 8 | sarkand
# Processing Record 9 of Set 8 | aksay
# Processing Record 10 of Set 8 | karaton
# Processing Record 11 of Set 8 | jacqueville
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | sakaraha
# Processing Record 14 of Set 8 | ust-ishim
# Processing Record 15 of Set 8 | la rioja
# Processing Record 16 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 17 of Set 8 | laguna
# Processing Record 18 of Set 8 | presidencia roque saenz pena
# Processing Record 19 of Set 8 | tautira
# Processing Record 20 of Set 8 | kahului
# Processing Record 21 of Set 8 | hirado
# Processing Record 22 of Set 8 | cuamba
# Processing Record 23 of Set 8 | alizai
# Processing Record 24 of Set 8 | keerbergen
# Processing Record 25 of Set 8 | bairiki
# Processing Record 26 of Set 8 | tura
# Processing Record 27 of Set 8 | tsabong
# Processing Record 28 of Set 8 | yarmouth
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | tuatapere
# Processing Record 31 of Set 8 | boffa
# Processing Record 32 of Set 8 | mayo
# Processing Record 33 of Set 8 | kourou
# Processing Record 34 of Set 8 | grants pass
# Processing Record 35 of Set 8 | marion
# Processing Record 36 of Set 8 | fukue
# Processing Record 37 of Set 8 | edgewater
# Processing Record 38 of Set 8 | natalinsk
# Processing Record 39 of Set 8 | skovorodino
# Processing Record 40 of Set 8 | atambua
# Processing Record 41 of Set 8 | highland springs
# Processing Record 42 of Set 8 | pangody
# Processing Record 43 of Set 8 | sioux lookout
# Processing Record 44 of Set 8 | asau
# Processing Record 45 of Set 8 | prabumulih
# Processing Record 46 of Set 8 | peniche
# Processing Record 47 of Set 8 | heihe
# Processing Record 48 of Set 8 | oriximina
# Processing Record 49 of Set 8 | soria
# Processing Record 50 of Set 8 | esperance
# Processing Record 1 of Set 9 | savannah bight
# Processing Record 2 of Set 9 | maryborough
# Processing Record 3 of Set 9 | college
# Processing Record 4 of Set 9 | anadyr
# Processing Record 5 of Set 9 | florianopolis
# Processing Record 6 of Set 9 | high level
# Processing Record 7 of Set 9 | novyy urengoy
# Processing Record 8 of Set 9 | urumqi
# Processing Record 9 of Set 9 | tomigusuku
# Processing Record 10 of Set 9 | fairview
# Processing Record 11 of Set 9 | port loko
# Processing Record 12 of Set 9 | bengkulu
# Processing Record 13 of Set 9 | port lavaca
# Processing Record 14 of Set 9 | bud
# Processing Record 15 of Set 9 | kismayo
# Processing Record 16 of Set 9 | xunchang
# Processing Record 17 of Set 9 | amalapuram
# Processing Record 18 of Set 9 | saint-francois
# Processing Record 19 of Set 9 | svetlogorsk
# Processing Record 20 of Set 9 | kimbe
# Processing Record 21 of Set 9 | la tuque
# Processing Record 22 of Set 9 | shaikhpura
# Processing Record 23 of Set 9 | mabaruma
# Processing Record 24 of Set 9 | honningsvag
# Processing Record 25 of Set 9 | methoni
# Processing Record 26 of Set 9 | la asuncion
# Processing Record 27 of Set 9 | lodja
# Processing Record 28 of Set 9 | lubartow
# Processing Record 29 of Set 9 | coruripe
# Processing Record 30 of Set 9 | nago
# Processing Record 31 of Set 9 | kayes
# Processing Record 32 of Set 9 | redmond
# Processing Record 33 of Set 9 | hit
# Processing Record 34 of Set 9 | maldonado
# Processing Record 35 of Set 9 | chumikan
# Processing Record 36 of Set 9 | kodiak
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | the pas
# Processing Record 39 of Set 9 | iqaluit
# Processing Record 40 of Set 9 | usakos
# Processing Record 41 of Set 9 | chifeng
# Processing Record 42 of Set 9 | kanniyakumari
# Processing Record 43 of Set 9 | suntar
# Processing Record 44 of Set 9 | hirara
# Processing Record 45 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 9 | petropavlovka
# Processing Record 47 of Set 9 | huarmey
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | cap malheureux
# Processing Record 50 of Set 9 | turukhansk
# Processing Record 1 of Set 10 | opuwo
# Processing Record 2 of Set 10 | san carlos de bariloche
# Processing Record 3 of Set 10 | belyy yar
# Processing Record 4 of Set 10 | fjellstrand
# Processing Record 5 of Set 10 | caohai
# Processing Record 6 of Set 10 | tabatinga
# Processing Record 7 of Set 10 | tanout
# Processing Record 8 of Set 10 | rio gallegos
# Processing Record 9 of Set 10 | matara
# Processing Record 10 of Set 10 | darnah
# Processing Record 11 of Set 10 | loikaw
# Processing Record 12 of Set 10 | wanaka
# Processing Record 13 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 10 | sola
# Processing Record 15 of Set 10 | hailar
# Processing Record 16 of Set 10 | omboue
# Processing Record 17 of Set 10 | vondrozo
# Processing Record 18 of Set 10 | alice springs
# Processing Record 19 of Set 10 | chiquilistlan
# Processing Record 20 of Set 10 | motygino
# Processing Record 21 of Set 10 | narasingapuram
# Processing Record 22 of Set 10 | smolenka
# Processing Record 23 of Set 10 | praia
# Processing Record 24 of Set 10 | inirida
# Processing Record 25 of Set 10 | heyang
# Processing Record 26 of Set 10 | gravdal
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 10 | port lincoln
# Processing Record 30 of Set 10 | cabo rojo
# Processing Record 31 of Set 10 | patiya
# Processing Record 32 of Set 10 | freetown
# Processing Record 33 of Set 10 | kirakira
# Processing Record 34 of Set 10 | mizdah
# Processing Record 35 of Set 10 | aksu
# Processing Record 36 of Set 10 | cabedelo
# Processing Record 37 of Set 10 | kyra
# Processing Record 38 of Set 10 | kaduqli
# Processing Record 39 of Set 10 | tabas
# Processing Record 40 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of Set 10 | jalu
# Processing Record 42 of Set 10 | bolkhov
# Processing Record 43 of Set 10 | eskilstuna
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | loukhi
# Processing Record 46 of Set 10 | te anau
# Processing Record 47 of Set 10 | vawkavysk
# Processing Record 48 of Set 10 | bogorodskoye
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | xining
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | luchegorsk
# Processing Record 3 of Set 11 | eureka
# Processing Record 4 of Set 11 | francistown
# Processing Record 5 of Set 11 | manadhoo
# Processing Record 6 of Set 11 | muroto
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | mawlaik
# Processing Record 9 of Set 11 | yar-sale
# Processing Record 10 of Set 11 | ishigaki
# Processing Record 11 of Set 11 | banda aceh
# Processing Record 12 of Set 11 | puerto narino
# Processing Record 13 of Set 11 | broken hill
# Processing Record 14 of Set 11 | treinta y tres
# Processing Record 15 of Set 11 | pafos
# Processing Record 16 of Set 11 | grindavik
# Processing Record 17 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | saint-augustin
# Processing Record 19 of Set 11 | byron bay
# Processing Record 20 of Set 11 | armenis
# Processing Record 21 of Set 11 | dolores
# Processing Record 22 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 11 | nipawin
# Processing Record 24 of Set 11 | bathsheba
# Processing Record 25 of Set 11 | severo-yeniseyskiy
# Processing Record 26 of Set 11 | batemans bay
# Processing Record 27 of Set 11 | westport
# Processing Record 28 of Set 11 | shenjiamen
# Processing Record 29 of Set 11 | coihaique
# Processing Record 30 of Set 11 | sai buri
# Processing Record 31 of Set 11 | san pedro
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | axim
# Processing Record 34 of Set 11 | missungwi
# Processing Record 35 of Set 11 | fort saint james
# Processing Record 36 of Set 11 | casa nova
# Processing Record 37 of Set 11 | jiuquan
# Processing Record 38 of Set 11 | roma
# Processing Record 39 of Set 11 | sven
# Processing Record 40 of Set 11 | noumea
# Processing Record 41 of Set 11 | pocone
# Processing Record 42 of Set 11 | araouane
# Processing Record 43 of Set 11 | sao joao da barra
# Processing Record 44 of Set 11 | priekule
# Processing Record 45 of Set 11 | carutapera
# Processing Record 46 of Set 11 | muli
# Processing Record 47 of Set 11 | taga
# Processing Record 48 of Set 11 | kushmurun
# Processing Record 49 of Set 11 | jumla
# Processing Record 50 of Set 11 | maceio
# Processing Record 1 of Set 12 | bukachacha
# Processing Record 2 of Set 12 | menomonie
# Processing Record 3 of Set 12 | manokwari
# Processing Record 4 of Set 12 | tukrah
# Processing Record 5 of Set 12 | agbor
# Processing Record 6 of Set 12 | duluth
# Processing Record 7 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 8 of Set 12 | akdepe
# Processing Record 9 of Set 12 | tepalcatepec
# Processing Record 10 of Set 12 | orapa
# Processing Record 11 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 12 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 12 | general roca
# Processing Record 14 of Set 12 | nuuk
# Processing Record 15 of Set 12 | la ronge
# Processing Record 16 of Set 12 | sukabumi
# Processing Record 17 of Set 12 | kuytun
# Processing Record 18 of Set 12 | jishou
# Processing Record 19 of Set 12 | mazagao
# Processing Record 20 of Set 12 | pontian kecil
# Processing Record 21 of Set 12 | tamandare
# Processing Record 22 of Set 12 | ferrol
# Processing Record 23 of Set 12 | marzuq
# Processing Record 24 of Set 12 | bako
# Processing Record 25 of Set 12 | alofi
# Processing Record 26 of Set 12 | nalbari
# Processing Record 27 of Set 12 | bonavista
# Processing Record 28 of Set 12 | tarakan
# Processing Record 29 of Set 12 | garowe
# Processing Record 30 of Set 12 | phan thiet
# Processing Record 31 of Set 12 | karlovac
# Processing Record 32 of Set 12 | palmer
# Processing Record 33 of Set 12 | severodvinsk
# Processing Record 34 of Set 12 | wewak
# Processing Record 35 of Set 12 | sugod
# Processing Record 36 of Set 12 | uyemskiy
# Processing Record 37 of Set 12 | maraa
# Processing Record 38 of Set 12 | trincomalee
# Processing Record 39 of Set 12 | karpogory
# Processing Record 40 of Set 12 | husavik
# Processing Record 41 of Set 12 | hami
# Processing Record 42 of Set 12 | port-gentil
# Processing Record 43 of Set 12 | jacareacanga
# Processing Record 44 of Set 12 | mitchell
# Processing Record 45 of Set 12 | burnie
# Processing Record 46 of Set 12 | baruun-urt
# Processing Record 47 of Set 12 | usinsk
# Processing Record 48 of Set 12 | amahai
# Processing Record 49 of Set 12 | daro
# Processing Record 50 of Set 12 | senneterre
# Processing Record 1 of Set 13 | donskoye
# Processing Record 2 of Set 13 | nsanje
# Processing Record 3 of Set 13 | sancti spiritus
# Processing Record 4 of Set 13 | tabuk
# Processing Record 5 of Set 13 | ust-maya
# Processing Record 6 of Set 13 | kampene
# Processing Record 7 of Set 13 | we
# City not found. Skipping...
# Processing Record 8 of Set 13 | guerrero negro
# Processing Record 9 of Set 13 | kafue
# Processing Record 10 of Set 13 | laon
# Processing Record 11 of Set 13 | durango
# Processing Record 12 of Set 13 | amos
# Processing Record 13 of Set 13 | tumut
# Processing Record 14 of Set 13 | christchurch
# Processing Record 15 of Set 13 | coahuayana
# Processing Record 16 of Set 13 | digha
# Processing Record 17 of Set 13 | general pico
# Processing Record 18 of Set 13 | peque
# Processing Record 19 of Set 13 | warwick
# Processing Record 20 of Set 13 | wronki
# Processing Record 21 of Set 13 | narsaq
# Processing Record 22 of Set 13 | ubinskoye
# Processing Record 23 of Set 13 | tucuma
# Processing Record 24 of Set 13 | vaitape
# Processing Record 25 of Set 13 | nanakuli
# Processing Record 26 of Set 13 | praia da vitoria
# Processing Record 27 of Set 13 | mareeba
# Processing Record 28 of Set 13 | upington
# Processing Record 29 of Set 13 | blackfalds
# Processing Record 30 of Set 13 | kemijarvi
# Processing Record 31 of Set 13 | berlevag
# Processing Record 32 of Set 13 | acapulco
# Processing Record 33 of Set 13 | areni
# Processing Record 34 of Set 13 | saryg-sep
# Processing Record 35 of Set 13 | viedma
# Processing Record 36 of Set 13 | aquiraz
# Processing Record 37 of Set 13 | luderitz
# Processing Record 38 of Set 13 | tizimin
# Processing Record 39 of Set 13 | cuencame
# Processing Record 40 of Set 13 | goldap
# Processing Record 41 of Set 13 | alashtar
# City not found. Skipping...
# Processing Record 42 of Set 13 | ilhabela
# Processing Record 43 of Set 13 | rostovka
# Processing Record 44 of Set 13 | illapel
# Processing Record 45 of Set 13 | smoky lake
# Processing Record 46 of Set 13 | port shepstone
# Processing Record 47 of Set 13 | tual
# Processing Record 48 of Set 13 | mercedes
# Processing Record 49 of Set 13 | katobu
# Processing Record 50 of Set 13 | probolinggo
# Processing Record 1 of Set 14 | gazanjyk
# Processing Record 2 of Set 14 | suez
# Processing Record 3 of Set 14 | telgte
# Processing Record 4 of Set 14 | shorkot
# Processing Record 5 of Set 14 | olafsvik
# Processing Record 6 of Set 14 | margate
# Processing Record 7 of Set 14 | sisimiut
# Processing Record 8 of Set 14 | new haven
# Processing Record 9 of Set 14 | karasburg
# Processing Record 10 of Set 14 | kango
# Processing Record 11 of Set 14 | kurilsk
# Processing Record 12 of Set 14 | isla mujeres
# Processing Record 13 of Set 14 | kangaatsiaq
# Processing Record 14 of Set 14 | okha
# Processing Record 15 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 14 | kudeyevskiy
# Processing Record 17 of Set 14 | umm lajj
# Processing Record 18 of Set 14 | casablanca
# Processing Record 19 of Set 14 | itupiranga
# Processing Record 20 of Set 14 | kunda
# Processing Record 21 of Set 14 | staryy nadym
# Processing Record 22 of Set 14 | coquimbo
# Processing Record 23 of Set 14 | port hedland
# Processing Record 24 of Set 14 | dhidhdhoo
# Processing Record 25 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | batetskiy
# Processing Record 27 of Set 14 | goderich
# Processing Record 28 of Set 14 | keuruu
# Processing Record 29 of Set 14 | baoqing
# Processing Record 30 of Set 14 | uyuni
# Processing Record 31 of Set 14 | tessalit
# Processing Record 32 of Set 14 | angoram
# Processing Record 33 of Set 14 | sault sainte marie
# Processing Record 34 of Set 14 | catuday
# Processing Record 35 of Set 14 | brigantine
# Processing Record 36 of Set 14 | marstal
# Processing Record 37 of Set 14 | borogontsy
# Processing Record 38 of Set 14 | dicabisagan
# Processing Record 39 of Set 14 | talakan
# Processing Record 40 of Set 14 | nome
# Processing Record 41 of Set 14 | sanming
# Processing Record 42 of Set 14 | mapiripan
# Processing Record 43 of Set 14 | zavodouspenskoye
# Processing Record 44 of Set 14 | hoshangabad
# Processing Record 45 of Set 14 | price
# Processing Record 46 of Set 14 | lensk
# Processing Record 47 of Set 14 | ballstad
# City not found. Skipping...
# Processing Record 48 of Set 14 | carira
# Processing Record 49 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 15 | bahir dar
# Processing Record 2 of Set 15 | flinders
# Processing Record 3 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 15 | talaya
# Processing Record 5 of Set 15 | kaili
# Processing Record 6 of Set 15 | potrero del llano
# Processing Record 7 of Set 15 | comodoro rivadavia
# Processing Record 8 of Set 15 | padang
# Processing Record 9 of Set 15 | iquique
# Processing Record 10 of Set 15 | kidal
# Processing Record 11 of Set 15 | bay roberts
# Processing Record 12 of Set 15 | shimminato
# Processing Record 13 of Set 15 | poum
# Processing Record 14 of Set 15 | luebo
# Processing Record 15 of Set 15 | mikumi
# Processing Record 16 of Set 15 | bismarck
# Processing Record 17 of Set 15 | zhuanghe
# Processing Record 18 of Set 15 | terney
# Processing Record 19 of Set 15 | natal
# Processing Record 20 of Set 15 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 21 of Set 15 | karatau
# Processing Record 22 of Set 15 | mahibadhoo
# Processing Record 23 of Set 15 | iquitos
# Processing Record 24 of Set 15 | monrovia
# Processing Record 25 of Set 15 | valparaiso
# Processing Record 26 of Set 15 | panama city
# Processing Record 27 of Set 15 | wanxian
# Processing Record 28 of Set 15 | anton lizardo
# Processing Record 29 of Set 15 | richards bay
# Processing Record 30 of Set 15 | hammerfest
# Processing Record 31 of Set 15 | comunal
# City not found. Skipping...
# Processing Record 32 of Set 15 | kharp
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | saint-joseph
# Processing Record 35 of Set 15 | emba
# Processing Record 36 of Set 15 | port macquarie
# Processing Record 37 of Set 15 | huallanca
# Processing Record 38 of Set 15 | kiunga
# Processing Record 39 of Set 15 | fomboni
# Processing Record 40 of Set 15 | ukiah
# Processing Record 41 of Set 15 | pakhtakoron
# Processing Record 42 of Set 15 | lulea
# Processing Record 43 of Set 15 | boende
# Processing Record 44 of Set 15 | tipuani
# Processing Record 45 of Set 15 | longido
# Processing Record 46 of Set 15 | malmyzh
# Processing Record 47 of Set 15 | san ignacio
# Processing Record 48 of Set 15 | kamariotissa
# Processing Record 49 of Set 15 | shingu
# Processing Record 50 of Set 15 | san cristobal
# Processing Record 1 of Set 16 | kisangani
# Processing Record 2 of Set 16 | chau doc
# Processing Record 3 of Set 16 | elizabeth city
# Processing Record 4 of Set 16 | krasnyy yar
# Processing Record 5 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 16 | soyo
# Processing Record 7 of Set 16 | joshimath
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Laukaa      RU  58.7372   29.8453     45.37        95         100
# 1      Tuktoyaktuk      CA  69.4541 -133.0374     24.80        80         100
# 2        Saskylakh      RU  71.9167  114.0833     32.16        93         100
# 3            Kapaa      US  22.0752 -159.3190     82.38        70           0
# 4          Mersing      MY   2.4312  103.8405     89.51        79          40
# 5      Clyde River      CA  70.4692  -68.5914     19.63        79           0
# 6  Bambous Virieux      MU -20.3428   57.7575     73.65        83          40
# 7            Bluff      NZ -46.6000  168.3333     51.80        68          73
# 8           Beloha      MG -25.1667   45.0500     63.21        95           4
# 9    Saint Anthony      US  45.0205  -93.2180     66.13        42           0
#
#    Wind Speed Current Description
# 0        5.93     overcast clouds
# 1       10.36     overcast clouds
# 2       10.96     overcast clouds
# 3       14.97           clear sky
# 4        5.75    scattered clouds
# 5        4.61           clear sky
# 6        8.05    scattered clouds
# 7        6.91       broken clouds
# 8        5.61           clear sky
# 9       13.80           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City                   703
# Country                703
# Lat                    703
# Lng                    703
# Max Temp               703
# Humidity               703
# Cloudiness             703
# Wind Speed             703
# Current Description    703
# dtype: int64
